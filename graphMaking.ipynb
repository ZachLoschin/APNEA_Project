# %%
import pandas as pd
import numpy as np
import openpyxl
import pathlib
import h5py
import os

# stats tabe
stats_table_path = pathlib.Path("Final_Table_For_Stats_Female.xlsx")

# Import Tables
stats_table = pd.read_excel(stats_table_path,engine='openpyxl')

# %%
import matplotlib.pyplot as plt
x = stats_table["HypopneaOverallIndex"]
y = stats_table["NREM23_SW_Density"]

import seaborn as sns

# plot 1 with axes level-plot
ax = sns.regplot(data=stats_table, x="HypopneaOverallIndex", y="NREM23_SW_Density").set(title="SW Density vs. HOI Female")
